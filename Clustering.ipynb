# %% [markdown]
# <a href="https://colab.research.google.com/github/goel-shaurya/Clustering_using_Pycaret/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - 04 (Clustering)
# ## Name - Shaurya Goel
# ## Roll Number - 102103339
# ## Subgroup - 3CO12

# %% [markdown]
# ### Importing the dataset uploaded on my github

# %%
import pandas as pd

# %%
my_data_set = pd.read_csv('uci_wine_dataset.csv')

# %%
my_data_set
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %% [markdown]
# ### Installing pycaret

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# ### K-Means Clustering Without Data Preprocessing

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(my_data_set)
# Out:
# <style type="text/css">
# #T_87826_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_87826" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87826_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_87826_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87826_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87826_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_87826_row0_col1" class="data row0 col1" >5365</td>
#     </tr>
#     <tr>
#       <th id="T_87826_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87826_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_87826_row1_col1" class="data row1 col1" >(178, 13)</td>
#     </tr>
#     <tr>
# ...

# %%
setup(my_data_set)
KMeanClusteringModel = create_model('kmeans',num_clusters = 4)
# Out:
# <style type="text/css">
# #T_0f67b_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0f67b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f67b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0f67b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f67b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f67b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0f67b_row0_col1" class="data row0 col1" >2395</td>
#     </tr>
#     <tr>
#       <th id="T_0f67b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f67b_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_0f67b_row1_col1" class="data row1 col1" >(178, 13)</td>
#     </tr>
#     <tr>
# ...

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43     15.600000        127           2.80
# 1      13.20        1.78  2.14     11.200000        100           2.65
# 2      13.16        2.36  2.67     18.600000        101           2.80
# 3      14.37        1.95  2.50     16.799999        113           3.85
# 4      13.24        2.59  2.87     21.000000        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45     20.500000         95           1.68
# 174    13.40        3.91  2.48     23.000000        102           1.80
# 175    13.27        4.28  2.26     20.000000        120           1.59
# 176    13.17        2.59  2.37     20.000000        120           1.65
# 177    14.13        4.10  2.74     24.500000         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
plot_model(KMeanClusteringModel, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(KMeanClusteringModel, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
k_means_sil = []
k_means_cali = []
k_means_devies = []

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)
print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)
print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_251ad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_251ad_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_251ad_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_251ad_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_251ad_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_251ad_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_251ad_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_251ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_251ad_row0_col0" class="data row0 col0" >0.5711</td>
#       <td id="T_251ad_row0_col1" class="data row0 col1" >561.8157</td>
# ...

# %% [markdown]
# ### K-Means Clustering With Transformation

# %%
setup(data = my_data_set,transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e82e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e82e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6e82e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6e82e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6e82e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6e82e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6e82e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e82e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e82e_row0_col0" class="data row0 col0" >0.3311</td>
#       <td id="T_6e82e_row0_col1" class="data row0 col1" >104.2042</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)
print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)
print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_32dcc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32dcc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_32dcc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_32dcc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_32dcc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_32dcc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_32dcc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32dcc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32dcc_row0_col0" class="data row0 col0" >0.3995</td>
#       <td id="T_32dcc_row0_col1" class="data row0 col1" >127.5525</td>
# ...

# %%
x = create_model('kmeans', num_clusters = 3)
plot_model(x, plot = 'distribution')
# Out:
# <style type="text/css">
# </style>
# <table id="T_95b65" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95b65_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95b65_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95b65_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95b65_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95b65_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95b65_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95b65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95b65_row0_col0" class="data row0 col0" >0.3995</td>
#       <td id="T_95b65_row0_col1" class="data row0 col1" >127.5525</td>
# ...

# %%
plot_model(x, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### K-Means Clustering with Normalization

# %%
setup(data = my_data_set, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2adf7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2adf7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2adf7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2adf7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2adf7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2adf7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2adf7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2adf7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2adf7_row0_col0" class="data row0 col0" >0.2580</td>
#       <td id="T_2adf7_row0_col1" class="data row0 col1" >55.7193</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)
print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)
print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_3f6ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f6ce_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3f6ce_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3f6ce_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3f6ce_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3f6ce_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3f6ce_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f6ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f6ce_row0_col0" class="data row0 col0" >0.2849</td>
#       <td id="T_3f6ce_row0_col1" class="data row0 col1" >70.9400</td>
# ...

# %%
x = create_model('kmeans', num_clusters = 4)
plot_model(x, plot = 'distribution')
# Out:
# <style type="text/css">
# </style>
# <table id="T_03d5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03d5a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_03d5a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_03d5a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_03d5a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_03d5a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_03d5a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03d5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03d5a_row0_col0" class="data row0 col0" >0.2580</td>
#       <td id="T_03d5a_row0_col1" class="data row0 col1" >55.7193</td>
# ...

# %%
plot_model(x, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### K-Means Clustering With PCA

# %%
setup(data = my_data_set, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a458c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a458c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a458c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a458c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a458c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a458c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a458c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a458c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a458c_row0_col0" class="data row0 col0" >0.5620</td>
#       <td id="T_a458c_row0_col1" class="data row0 col1" >708.0867</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)
print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)
print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_dd43c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd43c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dd43c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dd43c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dd43c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dd43c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dd43c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd43c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd43c_row0_col0" class="data row0 col0" >0.5711</td>
#       <td id="T_dd43c_row0_col1" class="data row0 col1" >561.8157</td>
# ...

# %%
x = create_model('kmeans', num_clusters = 4)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c6d3c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6d3c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c6d3c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c6d3c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c6d3c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c6d3c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c6d3c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6d3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6d3c_row0_col0" class="data row0 col0" >0.5620</td>
#       <td id="T_c6d3c_row0_col1" class="data row0 col1" >708.0867</td>
# ...

# %% [markdown]
# ### K-Means Clustering With Transformation + Normalization

# %%
setup(data = my_data_set, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_85546" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85546_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_85546_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_85546_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_85546_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_85546_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_85546_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85546_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85546_row0_col0" class="data row0 col0" >0.2781</td>
#       <td id="T_85546_row0_col1" class="data row0 col1" >57.3851</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)
print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)
print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_69cc2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69cc2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_69cc2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_69cc2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_69cc2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_69cc2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_69cc2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69cc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69cc2_row0_col0" class="data row0 col0" >0.3012</td>
#       <td id="T_69cc2_row0_col1" class="data row0 col1" >73.1113</td>
# ...

# %%
x = create_model('kmeans', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbebc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbebc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bbebc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bbebc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bbebc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bbebc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bbebc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbebc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbebc_row0_col0" class="data row0 col0" >0.3012</td>
#       <td id="T_bbebc_row0_col1" class="data row0 col1" >73.1113</td>
# ...

# %% [markdown]
# ### K-Means Clustering With Transformation + Normalization + PCA

# %%
setup(data = my_data_set, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_975a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_975a4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_975a4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_975a4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_975a4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_975a4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_975a4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_975a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_975a4_row0_col0" class="data row0 col0" >0.2819</td>
#       <td id="T_975a4_row0_col1" class="data row0 col1" >57.0788</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)
print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)
print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c0733" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0733_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c0733_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c0733_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c0733_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c0733_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c0733_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0733_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0733_row0_col0" class="data row0 col0" >0.3012</td>
#       <td id="T_c0733_row0_col1" class="data row0 col1" >73.1113</td>
# ...

# %%
x = create_model('kmeans', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a318" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a318_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1a318_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1a318_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1a318_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1a318_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1a318_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a318_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a318_row0_col0" class="data row0 col0" >0.3012</td>
#       <td id="T_1a318_row0_col1" class="data row0 col1" >73.1113</td>
# ...

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# ### Hierarchical without Data Preprocessing

# %%
setup(my_data_set)
HierarchicalClustering = create_model('hclust')
# Out:
# <style type="text/css">
# #T_e09bb_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e09bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e09bb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e09bb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e09bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e09bb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e09bb_row0_col1" class="data row0 col1" >5138</td>
#     </tr>
#     <tr>
#       <th id="T_e09bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e09bb_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e09bb_row1_col1" class="data row1 col1" >(178, 13)</td>
#     </tr>
#     <tr>
# ...

# %%
plot_model(HierarchicalClustering, plot = 'elbow')

# %%
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)
print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)
print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a0db0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0db0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a0db0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a0db0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a0db0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a0db0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a0db0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0db0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0db0_row0_col0" class="data row0 col0" >0.5645</td>
#       <td id="T_a0db0_row0_col1" class="data row0 col1" >552.8517</td>
# ...

# %%
x = create_model('hclust', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a693f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a693f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a693f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a693f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a693f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a693f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a693f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a693f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a693f_row0_col0" class="data row0 col0" >0.5645</td>
#       <td id="T_a693f_row0_col1" class="data row0 col1" >552.8517</td>
# ...

# %% [markdown]
# ### Hierarchical Clustering With Transformation

# %%
setup(data = my_data_set, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
HierarchicalClustering = create_model('hclust')
plot_model(HierarchicalClustering, plot = 'elbow')
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)
print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)
print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
x = create_model('hclust', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8556" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8556_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e8556_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e8556_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e8556_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e8556_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e8556_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8556_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8556_row0_col0" class="data row0 col0" >0.3163</td>
#       <td id="T_e8556_row0_col1" class="data row0 col1" >93.7427</td>
# ...

# %% [markdown]
# ### Hierarchical Clustering With Normalization

# %%
setup(data = my_data_set, normalize = True, normalize_method = 'zscore', verbose=False)
HierarchicalClustering = create_model('hclust')
plot_model(HierarchicalClustering, plot = 'elbow')
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)
print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)
print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
x = create_model('hclust', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8eba7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eba7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8eba7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8eba7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8eba7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8eba7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8eba7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eba7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8eba7_row0_col0" class="data row0 col0" >0.2258</td>
#       <td id="T_8eba7_row0_col1" class="data row0 col1" >51.4641</td>
# ...

# %% [markdown]
# ### Hierarchical Clustering With PCA

# %%
setup(data = my_data_set, pca = True, pca_method = 'linear', verbose=False)
HierarchicalClustering = create_model('hclust')
plot_model(HierarchicalClustering, plot = 'elbow')
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)
print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)
print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
x = create_model('hclust', num_clusters = 4)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9202a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9202a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9202a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9202a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9202a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9202a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9202a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9202a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9202a_row0_col0" class="data row0 col0" >0.5607</td>
#       <td id="T_9202a_row0_col1" class="data row0 col1" >670.6260</td>
# ...

# %% [markdown]
# ### Hierarchical Clustering With Normalization + Transformation

# %%
setup(data = my_data_set, transformation = True, normalize = True,normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
HierarchicalClustering = create_model('hclust')
plot_model(HierarchicalClustering, plot = 'elbow')
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)
print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)
print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
x = create_model('hclust', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e002" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e002_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4e002_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4e002_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4e002_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4e002_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4e002_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e002_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e002_row0_col0" class="data row0 col0" >0.2517</td>
#       <td id="T_4e002_row0_col1" class="data row0 col1" >53.1303</td>
# ...

# %% [markdown]
# ### Hierarchical Clustering With Normalization + Transformation + PCA

# %%
setup(data = my_data_set, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
HierarchicalClustering = create_model('hclust')
plot_model(HierarchicalClustering, plot = 'elbow')
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)
print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)
print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
x = create_model('hclust', num_clusters = 3)
plot_model(x,'distribution')
plot_model(x,'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d4e1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d4e1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6d4e1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6d4e1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6d4e1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6d4e1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6d4e1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d4e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d4e1_row0_col0" class="data row0 col0" >0.2517</td>
#       <td id="T_6d4e1_row0_col1" class="data row0 col1" >53.1303</td>
# ...

# %% [markdown]
# ## Birch Clustering

# %% [markdown]
# ### Birch Clustering without Data Preprocessing

# %%
setup(data=my_data_set)
BirchClustering = create_model('birch')
plot_model(BirchClustering, plot='elbow')
print("For Cluster = 3")
x = create_model('birch', num_clusters=3)
print("For Cluster = 4")
x = create_model('birch', num_clusters=4)
print("For Cluster = 5")
x = create_model('birch', num_clusters=5)
x = create_model('birch', num_clusters=4)
plot_model(x, 'distribution')
plot_model(x, 'tsne')
# Out:
# <style type="text/css">
# #T_acaa2_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_acaa2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acaa2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_acaa2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acaa2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acaa2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_acaa2_row0_col1" class="data row0 col1" >3181</td>
#     </tr>
#     <tr>
#       <th id="T_acaa2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acaa2_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_acaa2_row1_col1" class="data row1 col1" >(178, 13)</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Birch Clustering With Transformation

# %%
setup(data = my_data_set, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
BirchClustering = create_model('birch')
plot_model(BirchClustering, plot='elbow')
print("For Cluster = 3")
x = create_model('birch', num_clusters=3)
print("For Cluster = 4")
x = create_model('birch', num_clusters=4)
print("For Cluster = 5")
x = create_model('birch', num_clusters=5)
x = create_model('birch', num_clusters=4)
plot_model(x, 'distribution')
plot_model(x, 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cdbc7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdbc7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cdbc7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cdbc7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cdbc7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cdbc7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cdbc7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdbc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdbc7_row0_col0" class="data row0 col0" >0.3116</td>
#       <td id="T_cdbc7_row0_col1" class="data row0 col1" >91.6434</td>
# ...

# %% [markdown]
# ### Birch Clustering With Normalization

# %%
setup(data = my_data_set, normalize = True, normalize_method = 'zscore', verbose=False)
BirchClustering = create_model('birch')
plot_model(BirchClustering, plot='elbow')
print("For Cluster = 3")
x = create_model('birch', num_clusters=3)
print("For Cluster = 4")
x = create_model('birch', num_clusters=4)
print("For Cluster = 5")
x = create_model('birch', num_clusters=5)
x = create_model('birch', num_clusters=3)
plot_model(x, 'distribution')
plot_model(x, 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a37f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a37f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0a37f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0a37f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0a37f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0a37f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0a37f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a37f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a37f_row0_col0" class="data row0 col0" >0.2258</td>
#       <td id="T_0a37f_row0_col1" class="data row0 col1" >51.4641</td>
# ...

# %% [markdown]
# ### Birch Clustering With PCA

# %%
setup(data = my_data_set, pca = True, pca_method = 'linear', verbose=False)
BirchClustering = create_model('birch')
plot_model(BirchClustering, plot='elbow')
print("For Cluster = 3")
x = create_model('birch', num_clusters=3)
print("For Cluster = 4")
x = create_model('birch', num_clusters=4)
print("For Cluster = 5")
x = create_model('birch', num_clusters=5)
x = create_model('birch', num_clusters=4)
plot_model(x, 'distribution')
plot_model(x, 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6300" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6300_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d6300_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d6300_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d6300_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d6300_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d6300_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6300_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6300_row0_col0" class="data row0 col0" >0.5607</td>
#       <td id="T_d6300_row0_col1" class="data row0 col1" >670.6260</td>
# ...

# %% [markdown]
# ### Birch Clustering With Transformation and Normalization

# %%
setup(data = my_data_set, transformation = True, normalize = True,normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
BirchClustering = create_model('birch')
plot_model(BirchClustering, plot='elbow')
print("For Cluster = 3")
x = create_model('birch', num_clusters=3)
print("For Cluster = 4")
x = create_model('birch', num_clusters=4)
print("For Cluster = 5")
x = create_model('birch', num_clusters=5)
x = create_model('birch', num_clusters=3)
plot_model(x, 'distribution')
plot_model(x, 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2dd56" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dd56_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2dd56_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2dd56_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2dd56_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2dd56_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2dd56_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dd56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2dd56_row0_col0" class="data row0 col0" >0.2517</td>
#       <td id="T_2dd56_row0_col1" class="data row0 col1" >53.1303</td>
# ...

# %% [markdown]
# ### Birch Clustering With Transformation, Normalization, PCA

# %%
setup(data = my_data_set, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
BirchClustering = create_model('birch')
plot_model(BirchClustering, plot='elbow')
print("For Cluster = 3")
x = create_model('birch', num_clusters=3)
print("For Cluster = 4")
x = create_model('birch', num_clusters=4)
print("For Cluster = 5")
x = create_model('birch', num_clusters=5)
x = create_model('birch', num_clusters=3)
plot_model(x, 'distribution')
plot_model(x, 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9e63" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9e63_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f9e63_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f9e63_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f9e63_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f9e63_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f9e63_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9e63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9e63_row0_col0" class="data row0 col0" >0.2517</td>
#       <td id="T_f9e63_row0_col1" class="data row0 col1" >53.1303</td>
# ...

# %%
import pandas as pd
# Creating a dictionary with column names as keys
data = {
    'Parameters': ["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"],
    "No Data Preprocessing with c = 3 to 5": [[0.5711,0.5620,0.5082],[561.8157,708.0867,745.1974],[0.5342,0.5443,0.5744]],
    "Using Normalization with c = 3 to 5": [[0.2849,0.2599,0.2291],[70.9400,56.1960,47.310],[1.3892,1.8009,1.7353]],
    "Using Transformation with c = 3 to 5":  [[0.3995,0.3311,0.2636],[127.5525,104.2042,92.3124],[0.9493,1.1196,1.2690]],
    "Using PCA with c = 3 to 5":   [[0.5711,0.5606,0.5082],[561.8157,707.3763,745.1974],[0.5342,0.5445,0.5744]],
    "Using T+N with c = 3 to 5":  [[0.3012,0.2710,0.2600],[73.1113,57.3435,48.1361],[1.3610,1.7646,1.7882]],
    "Using T+N+PCA using c = 3 to 5": [[0.3012,0.2841,0.2328],[73.1113,56.8886,48.1254],[1.3610,1.7306,1.7517]]
}

# Creating DataFrame from dictionary
df = pd.DataFrame(data)
df
# Out:
#           Parameters No Data Preprocessing with c = 3 to 5  \
# 0         Silhouette               [0.5711, 0.562, 0.5082]
# 1  Calinski-Harabasz        [561.8157, 708.0867, 745.1974]
# 2     Davies-Bouldin              [0.5342, 0.5443, 0.5744]
#
#   Using Normalization with c = 3 to 5 Using Transformation with c = 3 to 5  \
# 0            [0.2849, 0.2599, 0.2291]             [0.3995, 0.3311, 0.2636]
# 1              [70.94, 56.196, 47.31]        [127.5525, 104.2042, 92.3124]
# 2            [1.3892, 1.8009, 1.7353]              [0.9493, 1.1196, 1.269]
#
#         Using PCA with c = 3 to 5    Using T+N with c = 3 to 5  \
# 0        [0.5711, 0.5606, 0.5082]        [0.3012, 0.271, 0.26]
# 1  [561.8157, 707.3763, 745.1974]  [73.1113, 57.3435, 48.1361]
# 2        [0.5342, 0.5445, 0.5744]      [1.361, 1.7646, 1.7882]
#
#   Using T+N+PCA using c = 3 to 5
# 0       [0.3012, 0.2841, 0.2328]
# 1    [73.1113, 56.8886, 48.1254]
# 2        [1.361, 1.7306, 1.7517]

# %%
csv_data = df.to_csv(index=False)

# %%
filename = 'k_means.csv'
with open(filename, 'w') as f:
    f.write(csv_data)

# %%
import pandas as pd
# Creating a dictionary with column names as keys
data1 = {
    'Parameters': ["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"],
    "No Data Preprocessing with c = 3 to 5": [[0.5645,0.5607,0.5075],[552.8517,670.6260,684.2226],[0.5357,0.5536,0.5513]],
    "Using Normalization with c = 3 to 5": [[0.2774,0.2258,0.1867],[67.6475,51.4641,43.6793],[1.4186,1.7887,1.9229]],
    "Using Transformation with c = 3 to 5":  [[0.3853,0.3163,0.3072],[119.6419,93.7427,82.8307],[0.9766,1.0767,1.2005]],
    "Using PCA with c = 3 to 5":   [[0.5645,0.5607,0.5075],[552.8517,670.6260,684.2226],[0.5357,0.5536,0.5513]],
    "Using T+N with c = 3 to 5":  [[0.2898,0.2517,0.2294],[68.9561,53.1303,44.7925],[1.3855,1.7044,1.8093]],
    "Using T+N+PCA using c = 3 to 5": [[0.2898,0.2517,0.2294],[68.9561,53.1303,44.7925],[1.3855,1.7044,1.8093]]
}

# Creating DataFrame from dictionary
df1 = pd.DataFrame(data1)
df1
# Out:
#           Parameters No Data Preprocessing with c = 3 to 5  \
# 0         Silhouette              [0.5645, 0.5607, 0.5075]
# 1  Calinski-Harabasz         [552.8517, 670.626, 684.2226]
# 2     Davies-Bouldin              [0.5357, 0.5536, 0.5513]
#
#   Using Normalization with c = 3 to 5 Using Transformation with c = 3 to 5  \
# 0            [0.2774, 0.2258, 0.1867]             [0.3853, 0.3163, 0.3072]
# 1         [67.6475, 51.4641, 43.6793]         [119.6419, 93.7427, 82.8307]
# 2            [1.4186, 1.7887, 1.9229]             [0.9766, 1.0767, 1.2005]
#
#        Using PCA with c = 3 to 5    Using T+N with c = 3 to 5  \
# 0       [0.5645, 0.5607, 0.5075]     [0.2898, 0.2517, 0.2294]
# 1  [552.8517, 670.626, 684.2226]  [68.9561, 53.1303, 44.7925]
# 2       [0.5357, 0.5536, 0.5513]     [1.3855, 1.7044, 1.8093]
#
#   Using T+N+PCA using c = 3 to 5
# 0       [0.2898, 0.2517, 0.2294]
# 1    [68.9561, 53.1303, 44.7925]
# 2       [1.3855, 1.7044, 1.8093]

# %%
csv_data = df1.to_csv(index=False)

# %%
filename = 'Hierarchical.csv'
with open(filename, 'w') as f:
    f.write(csv_data)

# %%
import pandas as pd
# Creating a dictionary with column names as keys
data2 = {
    'Parameters': ["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"],
    "No Data Preprocessing with c = 3 to 5": [[0.5645,0.5607,0.5075],[552.8517,670.6260,684.2226],[0.5357,0.5536,0.5513]],
    "Using Normalization with c = 3 to 5": [[0.2774,0.2258,0.1867],[67.6475,51.4641,43.6793],[1.4186,1.7887,1.9229]],
    "Using Transformation with c = 3 to 5":  [[0.3411,0.3116,0.2782],[101.7600,91.6434,81.8305],[1.0728,1.2993,1.3139]],
    "Using PCA with c = 3 to 5":   [[0.5645,0.5607,0.5075],[552.8517,670.6260,684.2226],[0.5357,0.5536,0.5513]],
    "Using T+N with c = 3 to 5":  [[0.2898,0.2517,0.2294],[68.9561,53.1303,44.7925],[1.3855,1.7044,1.8093]],
    "Using T+N+PCA using c = 3 to 5": [[0.2898,0.2517,0.2294],[68.9561,53.1303,44.7925],[1.3855,1.7044,1.8093]]
}

# Creating DataFrame from dictionary
df2 = pd.DataFrame(data2)
df2
# Out:
#           Parameters No Data Preprocessing with c = 3 to 5  \
# 0         Silhouette              [0.5645, 0.5607, 0.5075]
# 1  Calinski-Harabasz         [552.8517, 670.626, 684.2226]
# 2     Davies-Bouldin              [0.5357, 0.5536, 0.5513]
#
#   Using Normalization with c = 3 to 5 Using Transformation with c = 3 to 5  \
# 0            [0.2774, 0.2258, 0.1867]             [0.3411, 0.3116, 0.2782]
# 1         [67.6475, 51.4641, 43.6793]           [101.76, 91.6434, 81.8305]
# 2            [1.4186, 1.7887, 1.9229]             [1.0728, 1.2993, 1.3139]
#
#        Using PCA with c = 3 to 5    Using T+N with c = 3 to 5  \
# 0       [0.5645, 0.5607, 0.5075]     [0.2898, 0.2517, 0.2294]
# 1  [552.8517, 670.626, 684.2226]  [68.9561, 53.1303, 44.7925]
# 2       [0.5357, 0.5536, 0.5513]     [1.3855, 1.7044, 1.8093]
#
#   Using T+N+PCA using c = 3 to 5
# 0       [0.2898, 0.2517, 0.2294]
# 1    [68.9561, 53.1303, 44.7925]
# 2       [1.3855, 1.7044, 1.8093]

# %%
csv_data = df2.to_csv(index=False)
filename = 'Birch.csv'
with open(filename, 'w') as f:
    f.write(csv_data)
